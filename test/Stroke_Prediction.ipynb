# %%
from datetime import date, timedelta
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'whitegrid', color_codes = True)
# %matplotlib inline

# %%
#pip install xlrd

# %%
train =pd.read_excel("../test/healthcare-dataset-stroke-data.xls")

# %%
train.head(20)
# Out:
#     Unnamed: 0  Gender Age Group            BMI Ever_married      Work_type  \
# 0            0    Male     60-79        Obesity          Yes        Private
# 1            1  Female     60-79            NaN          Yes  Self-employed
# 2            2    Male       80+        Obesity          Yes        Private
# 3            3  Female     40-59        Obesity          Yes        Private
# 4            4  Female     60-79  Normal weight          Yes  Self-employed
# 5            5    Male       80+    Over weight          Yes        Private
# 6            6    Male     60-79    Over weight          Yes        Private
# 7            7  Female     60-79  Normal weight           No        Private
# 8            8  Female     40-59            NaN          Yes        Private
# 9            9  Female     60-79  Normal weight          Yes        Private
# 10          10  Female       80+    Over weight          Yes        Private
# 11          11  Female     60-79        Obesity          Yes       Govt_job
# 12          12  Female     40-59    Over weight          Yes        Private
# 13          13    Male     60-79            NaN          Yes        Private
# 14          14  Female     60-79    Over weight          Yes        Private
# 15          15  Female     40-59        Obesity          Yes  Self-employed
# 16          16    Male     60-79        Obesity          Yes        Private
# 17          17    Male     60-79    Over weight          Yes        Private
# 18          18  Female     60-79        Obesity           No        Private
# 19          19    Male     40-59            NaN           No       Govt_job
#
#    Residence_type Heart_disease Hypertension  avg_glucose_level  \
# 0           Urban           Yes           No             228.69
# 1           Rural            No           No             202.21
# 2           Rural           Yes           No             105.92
# 3           Urban            No           No             171.23
# 4           Rural            No          Yes             174.12
# 5           Urban            No           No             186.21
# 6           Rural           Yes          Yes              70.09
# 7           Urban            No           No              94.39
# 8           Rural            No           No              76.15
# 9           Urban            No           No              58.57
# 10          Rural            No          Yes              80.43
# 11          Rural           Yes           No             120.46
# 12          Urban            No           No             104.51
# 13          Urban           Yes           No             219.84
# 14          Urban           Yes           No             214.09
# 15          Rural            No          Yes             167.41
# 16          Urban           Yes           No             191.61
# 17          Urban            No          Yes             221.29
# 18          Urban            No           No              89.22
# 19          Urban           Yes           No             217.08
#
#           Smoking_status Stroke
# 0        formerly smoked    Yes
# 1           never smoked    Yes
# 2           never smoked    Yes
# 3                 smokes    Yes
# 4           never smoked    Yes
# 5        formerly smoked    Yes
# 6           never smoked    Yes
# 7           never smoked    Yes
# 8   Prefer Not to Answer    Yes
# 9   Prefer Not to Answer    Yes
# 10          never smoked    Yes
# 11                smokes    Yes
# 12                smokes    Yes
# 13  Prefer Not to Answer    Yes
# 14          never smoked    Yes
# 15          never smoked    Yes
# 16                smokes    Yes
# 17                smokes    Yes
# 18          never smoked    Yes
# 19  Prefer Not to Answer    Yes

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
# Unnamed: 0           5110 non-null int64
# Gender               5110 non-null object
# Age Group            5110 non-null object
# BMI                  4909 non-null object
# Ever_married         5110 non-null object
# Work_type            5110 non-null object
# Residence_type       5110 non-null object
# Heart_disease        5110 non-null object
# Hypertension         5110 non-null object
# avg_glucose_level    5110 non-null float64
# Smoking_status       5110 non-null object
# Stroke               5110 non-null object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 479.2+ KB

# %%
train.shape
# Out:
# (5110, 12)

# %%
train.isnull().sum()
# Out:
# Unnamed: 0             0
# Gender                 0
# Age Group              0
# BMI                  201
# Ever_married           0
# Work_type              0
# Residence_type         0
# Heart_disease          0
# Hypertension           0
# avg_glucose_level      0
# Smoking_status         0
# Stroke                 0
# dtype: int64

# %%
#train['smoking_status'].value_counts(normalize=True, dropna=False)

# %%
train.head()
# Out:
#    Unnamed: 0  Gender Age Group            BMI Ever_married      Work_type  \
# 0           0    Male     60-79        Obesity          Yes        Private
# 1           1  Female     60-79            NaN          Yes  Self-employed
# 2           2    Male       80+        Obesity          Yes        Private
# 3           3  Female     40-59        Obesity          Yes        Private
# 4           4  Female     60-79  Normal weight          Yes  Self-employed
#
#   Residence_type Heart_disease Hypertension  avg_glucose_level  \
# 0          Urban           Yes           No             228.69
# 1          Rural            No           No             202.21
# 2          Rural           Yes           No             105.92
# 3          Urban            No           No             171.23
# 4          Rural            No          Yes             174.12
#
#     Smoking_status Stroke
# 0  formerly smoked    Yes
# 1     never smoked    Yes
# 2     never smoked    Yes
# 3           smokes    Yes
# 4     never smoked    Yes

# %%
#train['stroke'] = train['stroke'].map(
                  # {1:'Yes' ,0:'No'})
#train['hypertension'] = train['hypertension'].map(
                   #{1:'Yes' ,0:'No'})
#train['heart_disease'] = train['heart_disease'].map(
                   #{1:'Yes' ,0:'No'})

# %%
train.head()
# Out:
#    Unnamed: 0  Gender Age Group            BMI Ever_married      Work_type  \
# 0           0    Male     60-79        Obesity          Yes        Private
# 1           1  Female     60-79            NaN          Yes  Self-employed
# 2           2    Male       80+        Obesity          Yes        Private
# 3           3  Female     40-59        Obesity          Yes        Private
# 4           4  Female     60-79  Normal weight          Yes  Self-employed
#
#   Residence_type Heart_disease Hypertension  avg_glucose_level  \
# 0          Urban           Yes           No             228.69
# 1          Rural            No           No             202.21
# 2          Rural           Yes           No             105.92
# 3          Urban            No           No             171.23
# 4          Rural            No          Yes             174.12
#
#     Smoking_status Stroke
# 0  formerly smoked    Yes
# 1     never smoked    Yes
# 2     never smoked    Yes
# 3           smokes    Yes
# 4     never smoked    Yes

# %%
#train.groupby('age', as_index=False)['bmi'].mean()

# %%
#train['age'] = train['age'].apply(lambda x : round(x))

# %%
#category = pd.cut(train.age,bins=[0,20,39,59,79,99],labels=['<20','20-39','40-59','60-79','80+'])
#train.insert(6,'Age Group',category)

# %%
#category = pd.cut(train.bmi,bins=[0,18.5,24.9,29.9,97.6],labels=['Under weight','Normal weight','Over weight','Obesity'])
#train.insert(6,'BMI',category)

# %%
#train['bmi'].max()

# %%
train = train.dropna()
print(train)
# Out:
#       Unnamed: 0  Gender Age Group            BMI Ever_married      Work_type  \
# 0              0    Male     60-79        Obesity          Yes        Private
# 2              2    Male       80+        Obesity          Yes        Private
# 3              3  Female     40-59        Obesity          Yes        Private
# 4              4  Female     60-79  Normal weight          Yes  Self-employed
# 5              5    Male       80+    Over weight          Yes        Private
# ...          ...     ...       ...            ...          ...            ...
# 5104        5104  Female       <20  Normal weight           No       Studying
# 5106        5106  Female       80+        Obesity          Yes  Self-employed
# 5107        5107  Female     20-39        Obesity          Yes  Self-employed
# 5108        5108    Male     40-59    Over weight          Yes        Private
# 5109        5109  Female     40-59    Over weight          Yes       Govt_job
#
#      Residence_type Heart_disease Hypertension  avg_glucose_level  \
# 0             Urban           Yes           No             228.69
# 2             Rural           Yes           No             105.92
# 3             Urban            No           No             171.23
# 4             Rural            No          Yes             174.12
# 5             Urban            No           No             186.21
# ...             ...           ...          ...                ...
# 5104          Rural            No           No             103.08
# 5106          Urban            No           No             125.20
# 5107          Rural            No           No              82.99
# 5108          Rural            No           No             166.29
# 5109          Urban            No           No              85.28
#
#             Smoking_status Stroke
# 0          formerly smoked    Yes
# 2             never smoked    Yes
# 3                   smokes    Yes
# 4             never smoked    Yes
# 5          formerly smoked    Yes
# ...                    ...    ...
# 5104  Prefer Not to Answer     No
# 5106          never smoked     No
# 5107          never smoked     No
# 5108       formerly smoked     No
# 5109  Prefer Not to Answer     No
#
# [4909 rows x 12 columns]

# %%
train.head()
# Out:
#    Unnamed: 0  Gender Age Group            BMI Ever_married      Work_type  \
# 0           0    Male     60-79        Obesity          Yes        Private
# 2           2    Male       80+        Obesity          Yes        Private
# 3           3  Female     40-59        Obesity          Yes        Private
# 4           4  Female     60-79  Normal weight          Yes  Self-employed
# 5           5    Male       80+    Over weight          Yes        Private
#
#   Residence_type Heart_disease Hypertension  avg_glucose_level  \
# 0          Urban           Yes           No             228.69
# 2          Rural           Yes           No             105.92
# 3          Urban            No           No             171.23
# 4          Rural            No          Yes             174.12
# 5          Urban            No           No             186.21
#
#     Smoking_status Stroke
# 0  formerly smoked    Yes
# 2     never smoked    Yes
# 3           smokes    Yes
# 4     never smoked    Yes
# 5  formerly smoked    Yes

# %%
#pip install xlwt

# %%
writer = pd.ExcelWriter('../test/healthcare-dataset-stroke-data.xls')

# %%
train.to_excel(writer)

# %%
writer.save()

# %%
print('DataFrame is written successfully to Excel File.')
# Out:
# DataFrame is written successfully to Excel File.
