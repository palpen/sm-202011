# %%
import pathlib
import time

import pandas as pd
import numpy as np
import feather
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
MAIN_PATH = pathlib.Path('/Users/palermopenano/personal/sm-202011/project_2')
num_days_preds = 16        # number of days into the future to predict (y values)
num_days = 6

# %% [markdown]
# # Load data

# %%
X_train = feather.read_dataframe(MAIN_PATH / 'tmp/X_train')
y_train = feather.read_dataframe(MAIN_PATH / 'tmp/y_train')
X_val = feather.read_dataframe(MAIN_PATH / 'tmp/X_val')
y_val = feather.read_dataframe(MAIN_PATH / 'tmp/y_val')
X_test = feather.read_dataframe(MAIN_PATH / 'tmp/X_test')
items = feather.read_dataframe(MAIN_PATH / 'tmp/items')

# %%
params = {
    'num_leaves': 80,
    'objective': 'regression',
    'min_data_in_leaf': 200,
    'learning_rate': 0.02,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.7,
    'bagging_freq': 1,
    'metric': 'l2',
    'num_threads': 16
}

MAX_ROUNDS = 5000

# %%
start = time.time()

val_pred = []
test_pred = []
cate_vars = []

for i in range(num_days_preds):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    
    dtrain = lgb.Dataset(
        X_train, label=y_train.iloc[:, i],
        categorical_feature=cate_vars,
        weight=pd.concat([items["perishable"]] * num_days) * 0.25 + 1  # items marked as perishable is given a weight of .25; others are 1
    )
    dval = lgb.Dataset(
        X_val, label=y_val.iloc[:, i],
        categorical_feature=cate_vars,
        weight=items["perishable"] * 0.25 + 1
    )
    bst = lgb.train(
        params, dtrain, num_boost_round=MAX_ROUNDS,
        valid_sets=[dtrain, dval], early_stopping_rounds=125, verbose_eval=50
    )
    
    # Interesting trick!
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    
    val_pred.append(
        bst.predict(X_val, 
                    num_iteration=bst.best_iteration or MAX_ROUNDS)
    )
    test_pred.append(
        bst.predict(X_test, 
                    num_iteration=bst.best_iteration or MAX_ROUNDS)
    )


print("\nValidation mse:", 
      mean_squared_error(y_val, np.array(val_pred).transpose()))
weight = items['perishable'] * 0.25 + 1
err = (y_val - np.array(val_pred).transpose())**2
err = err.sum(axis=1) * weight
err = np.sqrt(err.sum() / weight.sum() / 16)
print("Validation nwrmsle = {}".format(err))
print(f"Time taken: {(time.time() - start) / 60} mins")
# Out:
# ==================================================
# Step 1
# ==================================================
# /Users/palermopenano/miniconda3/envs/sm/lib/python3.7/site-packages/lightgbm/basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.008467	valid_1's l2: 0.00853278
# [100]	training's l2: 0.00844278	valid_1's l2: 0.00853224
# [150]	training's l2: 0.00842253	valid_1's l2: 0.00853325
# [200]	training's l2: 0.00840475	valid_1's l2: 0.00853439
# Early stopping, best iteration is:
# [75]	training's l2: 0.00845423	valid_1's l2: 0.00853175
# item_nbr: 126.59
# class: 117.31
# max_140: 104.36
# mean_140_decay: 78.99
# store_nbr: 62.70
# mean_140: 57.11
# std_140: 52.79
# cluster: 33.44
# family: 22.81
# mean_60_decay: 22.55
# mean_60: 20.93
# city: 20.26
# std_60: 18.97
# max_60: 18.00
# max_30: 17.61
# type: 17.16
# mean_30_decay: 13.70
# state: 11.38
# std_30: 10.51
# perishable: 10.29
# max_14: 9.78
# mean_30: 7.08
# mean_14_decay: 6.85
# std_14: 5.57
# mean_14: 5.12
# mean_7_decay: 4.38
# mean_7: 3.48
# diff_30_mean: 3.36
# std_7: 2.74
# mean_3_decay: 2.66
# diff_7_mean: 2.26
# diff_3_mean: 2.17
# max_7: 1.73
# diff_60_mean: 1.47
# diff_140_mean: 1.34
# std_3: 1.14
# diff_14_mean: 0.80
# mean_3: 0.63
# max_3: 0.30
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00769857	valid_1's l2: 0.00754087
# [100]	training's l2: 0.00767874	valid_1's l2: 0.00754007
# [150]	training's l2: 0.00766134	valid_1's l2: 0.00754103
# [200]	training's l2: 0.0076461	valid_1's l2: 0.00754198
# Early stopping, best iteration is:
# [82]	training's l2: 0.00768545	valid_1's l2: 0.00753977
# max_140: 127.25
# item_nbr: 85.43
# class: 77.25
# store_nbr: 55.65
# mean_140: 52.21
# std_140: 49.93
# mean_140_decay: 43.79
# cluster: 28.05
# mean_60_decay: 25.47
# family: 22.70
# max_60: 22.25
# max_30: 20.90
# mean_60: 19.22
# std_60: 18.25
# city: 16.08
# mean_30: 14.62
# std_30: 14.37
# mean_30_decay: 13.74
# type: 12.47
# state: 11.09
# mean_14_decay: 9.75
# mean_14: 6.66
# max_14: 6.08
# mean_3_decay: 5.99
# perishable: 5.42
# std_14: 5.19
# mean_7_decay: 5.17
# diff_7_mean: 4.17
# max_7: 3.96
# mean_7: 2.57
# std_3: 2.52
# diff_140_mean: 2.19
# mean_3: 1.79
# std_7: 1.54
# diff_3_mean: 1.39
# diff_14_mean: 1.36
# max_3: 1.34
# diff_60_mean: 1.30
# diff_30_mean: 1.29
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00857163	valid_1's l2: 0.00857455
# [100]	training's l2: 0.00854921	valid_1's l2: 0.00857603
# [150]	training's l2: 0.00852984	valid_1's l2: 0.00857775
# Early stopping, best iteration is:
# [46]	training's l2: 0.00857367	valid_1's l2: 0.00857444
# max_140: 79.80
# item_nbr: 69.29
# mean_140_decay: 66.88
# class: 63.02
# mean_140: 37.77
# store_nbr: 37.71
# std_140: 33.83
# max_60: 21.16
# family: 19.22
# cluster: 18.80
# mean_60_decay: 17.10
# std_60: 15.10
# mean_60: 14.87
# type: 12.80
# city: 12.09
# mean_30_decay: 8.75
# diff_14_mean: 8.33
# state: 7.93
# mean_30: 7.41
# max_30: 6.68
# mean_14_decay: 6.47
# std_30: 5.02
# max_7: 2.64
# max_14: 2.54
# mean_14: 2.14
# perishable: 1.93
# mean_7_decay: 1.66
# std_7: 1.44
# std_14: 1.21
# mean_7: 1.09
# diff_60_mean: 0.99
# diff_3_mean: 0.96
# diff_7_mean: 0.81
# diff_140_mean: 0.70
# std_3: 0.59
# mean_3_decay: 0.55
# mean_3: 0.46
# max_3: 0.29
# diff_30_mean: 0.19
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.0100242	valid_1's l2: 0.0102359
# [100]	training's l2: 0.0100002	valid_1's l2: 0.0102356
# [150]	training's l2: 0.00997904	valid_1's l2: 0.0102372
# [200]	training's l2: 0.00996051	valid_1's l2: 0.0102387
# Early stopping, best iteration is:
# [79]	training's l2: 0.0100097	valid_1's l2: 0.0102346
# item_nbr: 126.99
# class: 109.77
# mean_140_decay: 105.41
# max_140: 93.95
# store_nbr: 68.51
# mean_140: 58.31
# std_140: 56.57
# cluster: 29.21
# family: 27.40
# mean_60_decay: 26.40
# max_60: 24.58
# city: 23.21
# mean_60: 22.34
# std_60: 22.03
# type: 20.36
# state: 18.95
# mean_30: 14.04
# mean_30_decay: 13.33
# max_30: 11.01
# std_30: 10.11
# mean_14_decay: 6.48
# perishable: 6.40
# mean_7_decay: 4.97
# mean_3_decay: 4.72
# std_14: 3.90
# mean_14: 3.74
# max_7: 3.69
# diff_14_mean: 3.67
# max_14: 3.42
# std_3: 2.60
# std_7: 2.14
# diff_7_mean: 1.95
# mean_3: 1.88
# diff_140_mean: 1.54
# mean_7: 1.45
# diff_60_mean: 1.40
# diff_3_mean: 1.37
# max_3: 1.22
# diff_30_mean: 0.53
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.0102228	valid_1's l2: 0.01031
# [100]	training's l2: 0.0101985	valid_1's l2: 0.0103079
# [150]	training's l2: 0.0101778	valid_1's l2: 0.0103094
# [200]	training's l2: 0.0101595	valid_1's l2: 0.0103109
# Early stopping, best iteration is:
# [108]	training's l2: 0.0101953	valid_1's l2: 0.0103078
# item_nbr: 156.73
# class: 139.50
# mean_140_decay: 121.97
# max_140: 101.49
# store_nbr: 90.22
# mean_140: 86.23
# std_140: 70.89
# cluster: 48.84
# max_60: 43.80
# mean_60_decay: 39.12
# family: 38.97
# city: 33.84
# mean_60: 26.81
# std_60: 25.48
# state: 22.74
# type: 20.53
# max_30: 16.81
# mean_30: 14.07
# mean_30_decay: 13.42
# std_30: 11.48
# perishable: 11.37
# diff_60_mean: 9.58
# max_14: 8.24
# mean_14_decay: 8.11
# max_7: 6.46
# diff_140_mean: 6.45
# mean_14: 6.45
# mean_3_decay: 6.37
# std_14: 6.12
# mean_7_decay: 5.83
# mean_7: 3.43
# std_7: 2.81
# diff_7_mean: 2.74
# diff_14_mean: 2.30
# mean_3: 1.91
# std_3: 1.79
# diff_30_mean: 1.32
# max_3: 1.15
# diff_3_mean: 1.05
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00874727	valid_1's l2: 0.00913714
# [100]	training's l2: 0.00872488	valid_1's l2: 0.00913681
# [150]	training's l2: 0.0087057	valid_1's l2: 0.00913801
# [200]	training's l2: 0.00868907	valid_1's l2: 0.00913949
# Early stopping, best iteration is:
# [75]	training's l2: 0.00873544	valid_1's l2: 0.00913615
# mean_140_decay: 107.49
# item_nbr: 96.67
# max_140: 96.49
# class: 89.68
# mean_140: 61.64
# std_140: 51.41
# store_nbr: 47.46
# cluster: 34.36
# mean_60: 26.34
# family: 23.58
# mean_60_decay: 23.07
# std_60: 21.00
# type: 19.57
# city: 19.30
# max_60: 17.63
# state: 15.01
# max_30: 11.95
# mean_30_decay: 11.88
# mean_30: 10.72
# std_30: 6.97
# perishable: 6.40
# mean_14_decay: 4.32
# max_14: 3.92
# mean_14: 3.89
# mean_7_decay: 2.67
# max_7: 2.56
# std_14: 2.39
# diff_60_mean: 1.69
# std_7: 1.33
# mean_3_decay: 1.20
# mean_7: 1.01
# std_3: 0.98
# max_3: 0.88
# diff_140_mean: 0.68
# diff_7_mean: 0.47
# diff_3_mean: 0.38
# mean_3: 0.33
# diff_14_mean: 0.30
# diff_30_mean: 0.27
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00842839	valid_1's l2: 0.00989744
# [100]	training's l2: 0.00840556	valid_1's l2: 0.00989592
# [150]	training's l2: 0.00838575	valid_1's l2: 0.00989628
# [200]	training's l2: 0.0083683	valid_1's l2: 0.00989788
# Early stopping, best iteration is:
# [80]	training's l2: 0.00841438	valid_1's l2: 0.0098956
# item_nbr: 109.57
# max_140: 97.59
# class: 96.24
# mean_140_decay: 89.23
# store_nbr: 64.41
# mean_140: 63.77
# std_140: 51.77
# cluster: 33.94
# mean_60_decay: 30.98
# family: 26.39
# mean_60: 26.07
# max_60: 25.39
# std_60: 24.87
# city: 24.15
# state: 20.74
# max_30: 19.93
# type: 17.78
# mean_30_decay: 15.54
# mean_30: 15.27
# std_30: 12.69
# mean_14_decay: 8.84
# perishable: 7.99
# max_14: 7.10
# std_14: 4.30
# mean_14: 4.12
# mean_7_decay: 3.81
# diff_140_mean: 2.24
# diff_7_mean: 2.11
# mean_3_decay: 2.06
# max_7: 1.91
# diff_14_mean: 1.79
# std_7: 1.77
# mean_7: 1.72
# diff_60_mean: 1.05
# diff_3_mean: 0.95
# diff_30_mean: 0.72
# std_3: 0.19
# mean_3: 0.08
# median_3: 0.00
# min_3: 0.00
# max_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00857858	valid_1's l2: 0.00979821
# [100]	training's l2: 0.00855536	valid_1's l2: 0.0097962
# [150]	training's l2: 0.0085349	valid_1's l2: 0.00979659
# [200]	training's l2: 0.0085174	valid_1's l2: 0.00979848
# Early stopping, best iteration is:
# [100]	training's l2: 0.00855536	valid_1's l2: 0.0097962
# max_140: 160.94
# item_nbr: 134.66
# class: 128.02
# store_nbr: 77.75
# mean_140_decay: 73.32
# std_140: 71.03
# mean_140: 59.96
# cluster: 49.56
# mean_60_decay: 34.08
# family: 31.73
# city: 26.82
# std_60: 25.46
# type: 24.08
# max_60: 24.00
# mean_60: 23.54
# max_30: 22.55
# state: 19.92
# mean_30_decay: 18.30
# mean_30: 17.13
# std_30: 14.65
# perishable: 12.57
# mean_14_decay: 9.83
# max_14: 7.92
# mean_14: 6.27
# std_14: 5.75
# mean_7_decay: 4.97
# std_7: 4.69
# mean_3_decay: 4.35
# max_7: 3.62
# mean_7: 2.86
# diff_30_mean: 2.63
# diff_14_mean: 1.79
# diff_7_mean: 1.75
# mean_3: 1.68
# diff_60_mean: 1.68
# diff_3_mean: 1.41
# diff_140_mean: 1.17
# max_3: 1.13
# std_3: 1.13
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00762246	valid_1's l2: 0.00822233
# [100]	training's l2: 0.00760232	valid_1's l2: 0.00822207
# [150]	training's l2: 0.00758508	valid_1's l2: 0.00822333
# [200]	training's l2: 0.00756947	valid_1's l2: 0.00822491
# Early stopping, best iteration is:
# [82]	training's l2: 0.00760929	valid_1's l2: 0.00822168
# max_140: 106.60
# item_nbr: 84.57
# class: 77.40
# mean_140_decay: 62.53
# mean_140: 52.50
# std_140: 49.93
# store_nbr: 47.42
# cluster: 27.78
# max_60: 25.78
# mean_60_decay: 21.64
# std_60: 20.94
# mean_60: 20.88
# family: 19.25
# city: 18.82
# max_30: 16.21
# mean_30: 15.16
# mean_30_decay: 14.58
# std_30: 14.49
# type: 13.47
# state: 10.62
# mean_14_decay: 8.82
# std_14: 6.61
# mean_7_decay: 6.39
# perishable: 6.31
# max_14: 6.03
# max_7: 6.02
# std_7: 4.88
# mean_14: 4.88
# diff_7_mean: 3.70
# mean_7: 3.70
# mean_3_decay: 3.08
# diff_140_mean: 2.60
# diff_14_mean: 2.54
# diff_60_mean: 2.10
# mean_3: 1.40
# max_3: 0.70
# diff_3_mean: 0.56
# std_3: 0.52
# diff_30_mean: 0.30
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00853633	valid_1's l2: 0.00912711
# [100]	training's l2: 0.00851501	valid_1's l2: 0.00912692
# [150]	training's l2: 0.00849653	valid_1's l2: 0.00912887
# Early stopping, best iteration is:
# [68]	training's l2: 0.00852805	valid_1's l2: 0.00912642
# item_nbr: 94.93
# class: 84.05
# max_140: 81.20
# mean_140: 75.43
# mean_140_decay: 55.59
# store_nbr: 50.24
# std_140: 36.36
# max_60: 29.94
# cluster: 29.20
# family: 26.29
# mean_60_decay: 21.79
# std_60: 21.52
# mean_60: 18.39
# type: 17.65
# city: 13.79
# diff_7_mean: 12.41
# state: 11.57
# max_30: 11.16
# mean_30: 8.94
# max_14: 7.88
# mean_30_decay: 7.76
# diff_140_mean: 7.47
# std_30: 6.99
# perishable: 6.49
# mean_14_decay: 5.44
# mean_14: 4.78
# std_14: 4.71
# diff_3_mean: 2.59
# diff_14_mean: 2.09
# diff_30_mean: 2.03
# mean_7_decay: 1.99
# mean_7: 1.76
# max_7: 1.73
# std_3: 1.67
# mean_3_decay: 1.25
# diff_60_mean: 1.21
# std_7: 1.16
# mean_3: 0.73
# max_3: 0.64
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00998534	valid_1's l2: 0.00910065
# [100]	training's l2: 0.00996104	valid_1's l2: 0.00909852
# [150]	training's l2: 0.0099406	valid_1's l2: 0.00909911
# [200]	training's l2: 0.00992183	valid_1's l2: 0.00909996
# Early stopping, best iteration is:
# [101]	training's l2: 0.00996063	valid_1's l2: 0.00909844
# item_nbr: 138.84
# class: 129.46
# mean_140_decay: 121.82
# max_140: 116.73
# store_nbr: 86.11
# mean_140: 82.38
# std_140: 74.24
# cluster: 43.38
# mean_60_decay: 35.26
# family: 34.39
# max_60: 33.61
# mean_60: 32.10
# std_60: 31.68
# city: 26.92
# state: 20.98
# type: 20.45
# max_30: 19.95
# mean_30_decay: 17.94
# mean_30: 15.26
# std_30: 12.57
# diff_140_mean: 10.05
# mean_14: 8.90
# perishable: 7.06
# max_14: 6.60
# mean_14_decay: 6.28
# std_14: 5.99
# mean_3_decay: 4.60
# mean_7_decay: 3.49
# std_7: 3.08
# max_7: 2.76
# mean_7: 2.38
# diff_60_mean: 1.99
# diff_14_mean: 1.77
# diff_7_mean: 1.56
# mean_3: 1.24
# max_3: 0.96
# diff_30_mean: 0.85
# std_3: 0.65
# diff_3_mean: 0.51
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.0103939	valid_1's l2: 0.00961546
# [100]	training's l2: 0.0103689	valid_1's l2: 0.0096152
# [150]	training's l2: 0.0103475	valid_1's l2: 0.00961591
# [200]	training's l2: 0.0103282	valid_1's l2: 0.0096181
# Early stopping, best iteration is:
# [88]	training's l2: 0.0103745	valid_1's l2: 0.00961477
# mean_140_decay: 131.02
# item_nbr: 124.39
# class: 118.37
# max_140: 98.02
# mean_140: 80.09
# store_nbr: 74.61
# std_140: 57.77
# cluster: 45.80
# max_60: 33.34
# family: 32.28
# std_60: 32.12
# city: 30.28
# mean_60_decay: 28.85
# mean_60: 22.77
# state: 21.65
# type: 20.18
# max_30: 17.13
# mean_30_decay: 16.52
# std_30: 14.13
# mean_30: 12.76
# perishable: 10.51
# mean_14_decay: 6.15
# mean_14: 5.09
# std_14: 5.07
# max_7: 4.70
# max_14: 3.85
# diff_30_mean: 3.40
# diff_7_mean: 2.98
# diff_140_mean: 2.98
# mean_7_decay: 2.95
# diff_60_mean: 2.37
# mean_3_decay: 1.92
# std_7: 1.83
# mean_7: 1.68
# std_3: 1.68
# diff_14_mean: 1.45
# max_3: 0.82
# mean_3: 0.73
# diff_3_mean: 0.39
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00896361	valid_1's l2: 0.00845391
# [100]	training's l2: 0.00894051	valid_1's l2: 0.008454
# [150]	training's l2: 0.00892114	valid_1's l2: 0.00845625
# Early stopping, best iteration is:
# [74]	training's l2: 0.00895186	valid_1's l2: 0.00845338
# mean_140_decay: 97.13
# max_140: 95.23
# item_nbr: 94.66
# class: 85.87
# mean_140: 61.64
# std_140: 61.01
# store_nbr: 47.45
# cluster: 37.50
# std_60: 24.83
# family: 23.74
# city: 22.41
# mean_60_decay: 21.73
# mean_60: 21.17
# max_60: 20.47
# type: 17.72
# state: 16.16
# mean_30: 16.09
# max_30: 15.30
# mean_30_decay: 15.02
# std_30: 13.06
# max_14: 7.22
# perishable: 6.96
# mean_14: 4.47
# mean_14_decay: 4.40
# std_14: 3.48
# diff_30_mean: 3.31
# mean_7_decay: 2.28
# mean_7: 1.96
# diff_7_mean: 1.32
# mean_3_decay: 1.27
# max_7: 1.14
# diff_140_mean: 0.80
# mean_3: 0.76
# std_7: 0.72
# std_3: 0.70
# diff_14_mean: 0.62
# diff_3_mean: 0.59
# diff_60_mean: 0.56
# max_3: 0.08
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.0086293	valid_1's l2: 0.00840595
# [100]	training's l2: 0.00860614	valid_1's l2: 0.00840686
# [150]	training's l2: 0.0085866	valid_1's l2: 0.00840889
# Early stopping, best iteration is:
# [64]	training's l2: 0.00862241	valid_1's l2: 0.00840561
# class: 88.68
# mean_140_decay: 87.69
# max_140: 87.38
# item_nbr: 86.66
# mean_140: 51.49
# std_140: 43.56
# store_nbr: 43.33
# cluster: 29.34
# family: 25.03
# mean_60: 23.82
# max_60: 21.77
# mean_60_decay: 21.26
# std_60: 18.66
# city: 18.10
# type: 15.13
# max_30: 15.06
# state: 12.56
# mean_30: 12.51
# std_30: 10.95
# mean_30_decay: 9.76
# mean_14_decay: 9.12
# mean_3_decay: 5.47
# perishable: 4.96
# mean_7_decay: 3.48
# max_14: 3.01
# mean_14: 2.51
# mean_7: 2.34
# mean_3: 2.29
# std_3: 2.21
# diff_3_mean: 2.05
# std_7: 1.48
# diff_140_mean: 1.46
# diff_14_mean: 1.36
# max_7: 1.10
# std_14: 0.98
# diff_30_mean: 0.88
# diff_60_mean: 0.87
# diff_7_mean: 0.59
# max_3: 0.43
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00882676	valid_1's l2: 0.00860131
# [100]	training's l2: 0.00880205	valid_1's l2: 0.00860178
# [150]	training's l2: 0.0087815	valid_1's l2: 0.00860338
# Early stopping, best iteration is:
# [65]	training's l2: 0.00881905	valid_1's l2: 0.00860089
# max_140: 150.22
# item_nbr: 113.88
# class: 95.58
# store_nbr: 57.32
# mean_140_decay: 51.81
# mean_140: 46.18
# std_140: 42.57
# cluster: 39.97
# family: 25.81
# city: 18.88
# mean_60_decay: 18.57
# type: 18.45
# max_60: 17.14
# mean_60: 16.84
# std_60: 15.91
# perishable: 12.47
# state: 12.28
# mean_30_decay: 11.29
# max_30: 10.14
# max_14: 7.83
# mean_30: 7.80
# std_30: 6.82
# mean_14_decay: 6.34
# std_14: 5.46
# diff_140_mean: 4.65
# mean_14: 4.17
# diff_60_mean: 2.49
# mean_7_decay: 1.95
# mean_7: 1.85
# mean_3_decay: 1.49
# max_7: 1.37
# diff_30_mean: 1.27
# diff_3_mean: 1.21
# diff_14_mean: 1.11
# mean_3: 0.94
# diff_7_mean: 0.81
# std_7: 0.77
# std_3: 0.57
# max_3: 0.18
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.00776641	valid_1's l2: 0.00833164
# [100]	training's l2: 0.0077464	valid_1's l2: 0.00833121
# [150]	training's l2: 0.0077289	valid_1's l2: 0.0083316
# [200]	training's l2: 0.00771369	valid_1's l2: 0.00833256
# Early stopping, best iteration is:
# [108]	training's l2: 0.00774344	valid_1's l2: 0.00833091
# max_140: 128.33
# item_nbr: 110.57
# class: 96.83
# mean_140_decay: 85.25
# mean_140: 68.45
# store_nbr: 67.58
# std_140: 67.31
# cluster: 37.02
# mean_60_decay: 36.39
# max_60: 33.28
# mean_60: 30.50
# std_60: 28.32
# family: 24.46
# city: 19.68
# type: 19.12
# state: 16.20
# mean_30_decay: 15.93
# max_30: 14.86
# mean_30: 13.29
# max_14: 12.49
# std_30: 11.83
# mean_14_decay: 9.50
# std_14: 8.18
# perishable: 6.95
# mean_14: 6.67
# diff_140_mean: 6.47
# max_7: 5.93
# diff_7_mean: 5.74
# mean_7_decay: 5.68
# std_7: 3.95
# mean_7: 2.62
# diff_60_mean: 2.44
# diff_14_mean: 2.08
# std_3: 2.06
# diff_3_mean: 1.43
# mean_3_decay: 1.32
# mean_3: 1.12
# diff_30_mean: 1.02
# max_3: 0.13
# median_3: 0.00
# min_3: 0.00
# median_7: 0.00
# min_7: 0.00
# median_14: 0.00
# min_14: 0.00
# median_30: 0.00
# min_30: 0.00
# median_60: 0.00
# min_60: 0.00
# median_140: 0.00
# min_140: 0.00
#
# Validation mse: 0.00889049829837749
# Validation nwrmsle = 0.09482499076981449
# Time taken: 2.182093417644501 mins
